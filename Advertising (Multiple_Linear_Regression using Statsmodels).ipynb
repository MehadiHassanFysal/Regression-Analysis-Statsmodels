# %% [markdown]
# ## Multiple Linear Regression Model with Advertising Data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/MehadiHassanFysal/Regression-Analysis-Statsmodels/refs/heads/main/Advertising%20(Multiple_Linear_Regression%20using%20Statsmodels).csv")

# %%
df
# Out:
#         TV  radio  newspaper     sales
# 0    230.1   37.8       69.2  22100000
# 1     44.5   39.3       45.1  10400000
# 2     17.2   45.9       69.3   9300000
# 3    151.5   41.3       58.5  18500000
# 4    180.8   10.8       58.4  12900000
# ..     ...    ...        ...       ...
# 195   38.2    3.7       13.8   7600000
# 196   94.2    4.9        8.1   9700000
# 197  177.0    9.3        6.4  12800000
# 198  283.6   42.0       66.2  25500000
# 199  232.1    8.6        8.7  13400000
#
# [200 rows x 4 columns]

# %%
len(df)
# Out:
# 200

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 3, figsize = (16,6))

axes[0].scatter(df['TV'], df['sales'])
axes[0].set_ylabel("Sales")
axes[0].set_title("TV Spend")

axes[1].scatter(df['radio'], df['sales'])
axes[1].set_ylabel("Sales")
axes[1].set_title("Radio Spend")

axes[2].scatter(df['newspaper'], df['sales'])
axes[2].set_ylabel("Sales")
axes[2].set_title("Newspaper Spend")
# Out:
# Text(0.5, 1.0, 'Newspaper Spend')

# %%
sns.pairplot(df)

# %% [markdown]
# ## **Statistical Approach:**
# # Introducting 'statsmodels'.

# %%
#import statsmodels.api as sm

# %%
import statsmodels.formula.api as smf

# %%
est = smf.ols(formula = 'sales ~ TV + radio + newspaper', data = df).fit()
#OLS-Ordinary Least Squares

# %%
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Fri, 23 Jan 2026   Prob (F-statistic):           1.58e-96
# Time:                        17:22:39   Log-Likelihood:                -3149.3
# No. Observations:                 200   AIC:                             6307.
# Df Residuals:                     196   BIC:                             6320.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.939e+06   3.12e+05      9.422      0.000    2.32e+06    3.55e+06
# TV          4.576e+04   1394.897     32.809      0.000     4.3e+04    4.85e+04
# radio       1.885e+05   8611.234     21.893      0.000    1.72e+05    2.06e+05
# newspaper  -1037.4930   5871.010     -0.177      0.860   -1.26e+04    1.05e+04
# ==============================================================================
# Omnibus:                       60.414   Durbin-Watson:                   2.084
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              151.241
# Skew:                          -1.327   Prob(JB):                     1.44e-33
# Kurtosis:                       6.332   Cond. No.                         454.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### OLS = Ordinary Least Squares
# #### coef = Coeficent
# #### std err = Standard Error
# #### P = P Value
# #### R-squared = R2 = Coefficient of Determination
# #### Df = Degree of Freedom
